# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from googletrans import Translator
from analysis_helpers import get_correlations
import simplemma

# %%
# Read the preprocessed dataset
df = pd.read_parquet('../data/used_car_dataset.parquet')
df.head()
# Out:
#    price (HUF)  condition                        design  \
# 0      6895000     Kitűnő                         Sedan
# 1      9999999  Megkímélt  Városi terepjáró (crossover)
# 2      4995000     Kitűnő  Városi terepjáró (crossover)
# 3      3499000     Kitűnő  Városi terepjáró (crossover)
# 4     12990000     Normál                         Coupe
#
#                            vehicle history         financing  \
# 0  Elérhető autó-előélet alvázszám alapján  25%-tól elvihető
# 1  Elérhető autó-előélet alvázszám alapján  20%-tól elvihető
# 2  Elérhető autó-előélet alvázszám alapján  20%-tól elvihető
# 3  Elérhető autó-előélet alvázszám alapján
# 4  Elérhető autó-előélet alvázszám alapján  20%-tól elvihető
#
#    clock position (km)  shippable persons number  number of doors  \
# 0               110000                       5.0              4.0
# 1               119300                       5.0              5.0
# 2                70000                       5.0              5.0
# 3               100000                       5.0              5.0
# 4                47336                       5.0              4.0
#
#             color  own weight (kg)  ...  hard drive  hdmi input door actuator  \
# 0  Fekete (metál)           1426.0  ...       False       False         False
# 1           Fehér           2150.0  ...       False       False         False
# 2             Kék           1200.0  ...       False       False         False
# 3        Sötétkék           1176.0  ...       False       False         False
# 4                           1490.0  ...       False       False         False
#
#   reversing camera input chrome rims  1 din  sliding door leather upholstery  \
# 0                  False       False  False         False              False
# 1                  False       False  False         False              False
# 2                  False       False  False         False              False
# 3                  False       False  False         False              False
# 4                  False       False  False         False               True
#
#   double-sided sliding door gesture control
# 0                     False           False
# 1                     False           False
# 2                     False           False
# 3                     False           False
# 4                     False           False
#
# [5 rows x 247 columns]

# %% [markdown]
# ### Get car brand

# %%
# Add brand from link
df['brand'] = [x[4] for x in df.link.str.split('/')]
df['brand'].head()
# Out:
# 0       volkswagen
# 1    mercedes-benz
# 2            dacia
# 3          renault
# 4    mercedes-benz
# Name: brand, dtype: object

# %%
# Color contains 2 peaces of inprmation the exact color and the is the car has metallic polish or not
df['metallic_polish'] = df['color'].str.contains('metál')
df['color'] = df['color'].str.replace(' (metál)', '', regex=False).str.lower()

# %% [markdown]
# ### Extract the city from the address
#
# If the car is advertised by a shop the first contact information is the name of the shop. If the car advertised by an individual then the first one is the address. If wh have the address then we can extract the city name from it. Luckily we have a csv with all the hungarian city names so we can find them in the addresses even if the format of the address is not uniform so we would struggle with writing a regex from this

# %%
df_hun_sattlements = pd.read_csv('all_hun_settlement.csv')

df_hun_sattlements['cleaned_settlement'] = df_hun_sattlements['settlement'].str.replace(r'Budapest.+', 'Budapest').str.lower().str.strip()
#df_hun_sattlements.drop_duplicates('cleand_settlement', inplace=True)

df_hun_sattlements.head()
# Out:
# /var/folders/6p/rn1y8jlj4q5fp4y6jrn3qslc0000gn/T/ipykernel_53055/2543547996.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_hun_sattlements['cleaned_settlement'] = df_hun_sattlements['settlement'].str.replace(r'Budapest.+', 'Budapest').str.lower().str.strip()
#     zip           settlement short  latitude  longitude cleaned_settlement
# 0  1011  Budapest I. kerület    BU   47.5011    19.0469           budapest
# 1  1012  Budapest I. kerület    BU   47.5000    19.0833           budapest
# 2  1013  Budapest I. kerület    BU   47.4961    19.0309           budapest
# 3  1014  Budapest I. kerület    BU   47.5034    19.0349           budapest
# 4  1015  Budapest I. kerület    BU   47.5000    19.0833           budapest

# %%
def get_city_from_zip(_zip):
    city = df_hun_sattlements[df_hun_sattlements.zip == _zip]['cleaned_settlement']
    if len(city) > 0:
        return city.values[0]

# %%
msk_is_salse_shop = df['buy_from_shop']
# If the car is advertised by a shop the first contact information is the name of the shop
# If the car advertised by an individual then the first one is the address
# First get the addresses in 1 column
address = pd.Series(np.where(msk_is_salse_shop, df.content_info_1, df.content_info_0))

# Convert it to lower case since we converted all the city names as well
address = address.str.lower()

# Remove "looking in map" additinal text that come form the scraping not part of the address
address = address.str.replace('térkép megtekintése', '', regex=False)

zip_code = address.str.replace('[^\d ]', '', regex=True)
zip_code = zip_code.str.extract("( \d\d\d\d )")[0].astype(float)
cities_based_on_zip = [
    get_city_from_zip(x) for x in zip_code
]

address_without_numbers = address.str.replace("[^a-záéíóöőúüű\s]", "", regex=True)

# Extract the city name from each address
df['city'] = address_without_numbers.str.extract(f"( {' | '.join(df_hun_sattlements['cleaned_settlement'].unique())} )")
df['city'] = df['city'].str.strip()

df['city'] = np.where(df['city'].isna(), cities_based_on_zip, df['city'])

# %%
# A lot of advertisemnt don't show address
df['city'].isna().mean()
# Out:
# 0.3153458415009801

# %% [markdown]
# ### Get take away discount values

# %%
# Take aways from X%
# Drop taken away from variable
df['financing'] = df['financing'].str.replace(r'\D', '', regex=True).replace({'':'100'}).astype(int)

# %%
df['financing'].value_counts()
# Out:
# 100    53955
# 20      9913
# 30      3155
# 25      2674
# 0        843
# 40       347
# 35       282
# 50       163
# 10        45
# 45        27
# 15        12
# 60         3
# 70         1
# Name: financing, dtype: int64

# %%
cols = df.columns
# Drop taken aw columsn to remove duplicated information
cols[cols.str.lower().str.contains('take')]
# Out:
# Index(['Take away from 20%', 'Can be taken away from 30%',
#        'Take away from 25%'],
#       dtype='object')

# %%
# Use years instead of days becuase this high resulution of the age doeasn't really matter on the other hand makes if harder to biuld model
df['age_year'] = (df['age_days']/365).astype(int)

# %% [markdown]
# ### Get freatures from description# Remuve unneccessary spaces
#
# (1. **Sentiment Analysis:**  **It would work only with english text! Do translation before!** You can perform sentiment analysis on the description to see if it's generally positive, negative, or neutral. This could be interesting to see if there's any correlation between the sentiment of the description and other variables.)
#
# 2. **Text Length:** The length of the description could be indicative of something. For instance, sellers who are more serious might write more detailed descriptions. You can easily calculate this with Python's `len()` function.
#
# 3. **Word Count:** Similar to text length, but this might give different results because it doesn't count characters but words. A higher word count might indicate a more complex description.
#
# 4. **Count of Specific Words:** You can count the occurrence of specific words that you think might be important. For example, if you're looking at car listings, words like "new", "used", "clean", "serviced" etc., might be of interest.
#
# 5. **Count of Capitalized Words:** Sellers might capitalize certain words to draw attention to them. Counting the number of capitalized words could be another feature.
#
# 6. **TF-IDF Scores:** This is a statistical measure used to evaluate how important a word is to a document in a collection or corpus. Words that are used frequently in a single document but not frequently in the corpus receive a higher TF-IDF score.

# %%
# Remuve unneccessary spaces
df['description'] = df['description'].str.strip() 
# Remove start word which means description
df['description'] = df['description'].str.replace(r'leírás\n','', regex=True)

# %%
df['description_length'] = df['description'].apply(len)
df['word_count'] = df['description'].apply(lambda x: len(x.split()))


# Sentiment analyses
# TODO: Translatie description
# df['description_polarity'] = df['description'].apply(lambda x: TextBlob(x).sentiment.polarity)
# df['description_subjectivity'] = df['description'].apply(lambda x: TextBlob(x).sentiment.subjectivity)

# %%
def lemmatize_text(text):
    mytokens = text.split()
    lemmetized_tokens = [simplemma.lemmatize(x, lang='hu') for x in mytokens]
    
    return ' '.join(lemmetized_tokens)

# %%
# Remove non-alpahbetic characters
df['description_lemmatized'] = df['description'].str.replace('[^a-záéíóöőúüű\s]', '', regex=True)

# Lemmatize
df['description_lemmatized'] = [lemmatize_text(x) for x in df['description_lemmatized']]

# Manula lemmatization for specail cases
word_map = {'cserél':'csere', 'garantál':'garancia', 
            'állapotú':'állapot', 'állap':'állapot', 'állapotot':'állapot', 'használat':'használ', 
            'ülése':'ülés', 'elektromosan':'elektromos', 'magyarországi':'magyarország',
            'megtekinthető':'megtekintés', 'ülése':'ülés', 'km':'kilométer',
            'gépjármű':'gépkocsi', 'autó':'gépkocsi'}

for k,v in word_map.items():
    df['description_lemmatized'] = df['description_lemmatized'].str.replace(k, v)

# %%
# 'hungarian_stop_words' is a list of stop words in Hungarian
with open('stopwords-hu.txt', 'r', encoding='utf-8') as f:
    hungarian_stop_words = [line.strip() for line in f]

# %%
# Create the TF-IDF vectorizer
vectorizer = TfidfVectorizer(stop_words=hungarian_stop_words, max_features=90)

# Apply the vectorizer
X = vectorizer.fit_transform(df['description_lemmatized'])

# Translate to inglis the feature names
translator = Translator()
translations = translator.translate(list(vectorizer.get_feature_names_out()), src='hu', dest='en')

# Create a dataframe from the features
tfidf_df = pd.DataFrame(X.toarray(), columns=['tfidf_'+x.text for x in translations])
# Out:
# /Users/davidszalai/anaconda3/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:409: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['stb', 'оda'] not in stop_words.
#   warnings.warn(

# %%
tfidf_df.rename(columns={'tfidf_sports':'tfidf_sport'}, inplace=True, )

# %%
vectorizer.get_feature_names_out()
# Out:
# array(['ablak', 'alap', 'alváz', 'automata', 'belső', 'beszámít',
#        'biztosítás', 'bőr', 'csere', 'csomag', 'db', 'egyeztetés', 'elad',
#        'elektromos', 'elvihető', 'elöl', 'es', 'eset', 'esztétika',
#        'extra', 'felszereltség', 'forgalom', 'friss', 'fényszóró',
#        'fűthető', 'garancia', 'gumi', 'gyári', 'gépkocsi', 'használ',
#        'hirdetés', 'hitel', 'hátsó', 'időpont', 'ig', 'jármű',
#        'karbantart', 'kerül', 'kilométer', 'klíma', 'kormány', 'kulcs',
#        'kér', 'köszön', 'külső', 'led', 'lehetséges', 'leinformálható',
#        'légzsák', 'magyar', 'magyarország', 'megbízható', 'megkímélt',
#        'megtekintés', 'minősül', 'motor', 'működik', 'műszaki',
#        'navigáció', 'nyári', 'olaj', 'rendelkezik', 'rendszer',
#        'rendszeres', 'stb', 'személyes', 'szerel', 'szerviz', 'szép',
#        'tart', 'tartalmaz', 'telefon', 'tempomat', 'tud', 'tulajdonos',
#        'téli', 'tükör', 'vezet', 'vált', 'vár', 'vásárlás', 'vásárol',
#        'vég', 'állapot', 'állítható', 'ár', 'érdeklődik', 'összes',
#        'ügyintézés', 'ülés'], dtype=object)

# %%
tfidf_df.columns.value_counts().head(10)
# Out:
# tfidf_window        1
# tfidf_service       1
# tfidf_personal      1
# tfidf_etc           1
# tfidf_regular       1
# tfidf_system        1
# tfidf_has           1
# tfidf_oil           1
# tfidf_summer        1
# tfidf_navigation    1
# dtype: int64

# %%
columns_to_drop = [
            'content_info_0',
            'content_info_1',
            'content_info_2',
            'content_info_3',
            'content_info_4',
            'content_info_5',
            'content_info_6',
            'upholstery color (1)',
            'upholstery color (2)',
            'Take away from 20%',
            'Take away from 25%',
            'Can be taken away from 30%',
            'description',
            'description_lemmatized'
        ]
for x in columns_to_drop:
    print(x)
# Out:
# content_info_0
# content_info_1
# content_info_2
# content_info_3
# content_info_4
# content_info_5
# content_info_6
# upholstery color (1)
# upholstery color (2)
# Take away from 20%
# Take away from 25%
# Can be taken away from 30%
# description
# description_lemmatized

# %%
# Join the new features to the original dataframe
df2 = pd.concat([df, tfidf_df], axis=1)

df2.drop(
    columns=[
     'content_info_0',
     'content_info_1',
     'content_info_2',
     'content_info_3',
     'content_info_4',
     'content_info_5',
     'upholstery color (1)',
     'upholstery color (2)',
     'content_info_6',
    'Take away from 20%',
    'Take away from 25%',
    'Can be taken away from 30%',
    'age_days',
    'description',
    'description_lemmatized'
    ],
    inplace=True
)

# %%
df2.head()
# Out:
#    price (HUF)  condition                        design  \
# 0      6895000     Kitűnő                         Sedan
# 1      9999999  Megkímélt  Városi terepjáró (crossover)
# 2      4995000     Kitűnő  Városi terepjáró (crossover)
# 3      3499000     Kitűnő  Városi terepjáró (crossover)
# 4     12990000     Normál                         Coupe
#
#                            vehicle history  financing  clock position (km)  \
# 0  Elérhető autó-előélet alvázszám alapján         25               110000
# 1  Elérhető autó-előélet alvázszám alapján         20               119300
# 2  Elérhető autó-előélet alvázszám alapján         20                70000
# 3  Elérhető autó-előélet alvázszám alapján        100               100000
# 4  Elérhető autó-előélet alvázszám alapján         20                47336
#
#    shippable persons number  number of doors     color  own weight (kg)  ...  \
# 0                       5.0              4.0    fekete           1426.0  ...
# 1                       5.0              5.0     fehér           2150.0  ...
# 2                       5.0              5.0       kék           1200.0  ...
# 3                       5.0              5.0  sötétkék           1176.0  ...
# 4                       5.0              4.0                     1490.0  ...
#
#    tfidf_buying  tfidf_buys tfidf_end tfidf_condition tfidf_adjustable  \
# 0      0.000000    0.000000  0.000000        0.136765         0.000000
# 1      0.229360    0.000000  0.000000        0.252778         0.000000
# 2      0.000000    0.000000  0.000000        0.156297         0.000000
# 3      0.128078    0.124196  0.240592        0.141155         0.142926
# 4      0.000000    0.000000  0.000000        0.000000         0.000000
#
#    tfidf_price  tfidf_inquire tfidf_all tfidf_administration tfidf_seat
# 0          0.0            0.0  0.000000             0.233220   0.000000
# 1          0.0            0.0  0.000000             0.000000   0.000000
# 2          0.0            0.0  0.000000             0.266528   0.000000
# 3          0.0            0.0  0.141467             0.120353   0.000000
# 4          0.0            0.0  0.000000             0.000000   0.117257
#
# [5 rows x 329 columns]

# %%
df2.set_index('link', inplace=True)

# %%
df_melt_corr = get_correlations(df2)
df_melt_corr
# Out:
#                            variable1                       variable2  \
# 1672  back summer tires rim diameter       summer tires rim diameter
# 2029  back winter tires rim diameter       winter tires rim diameter
# 3095              description_length                      word_count
# 1910   back winter tires apect ratio        winter tires apect ratio
# 1553   back summer tires apect ratio        summer tires apect ratio
# ...                              ...                             ...
# 1911  back winter tires rim diameter        winter tires apect ratio
# 2143          back summer tire width   back summer tires apect ratio
# 1554  back summer tires rim diameter        summer tires apect ratio
# 1671   back summer tires apect ratio       summer tires rim diameter
# 2262   back summer tires apect ratio  back summer tires rim diameter
#
#       correlation
# 1672     0.997407
# 2029     0.993658
# 3095     0.989647
# 1910     0.979885
# 1553     0.974668
# ...           ...
# 1911    -0.734149
# 2143    -0.745452
# 1554    -0.748433
# 1671    -0.765120
# 2262    -0.767937
#
# [6903 rows x 3 columns]

# %%
df_high_corr = df_melt_corr[df_melt_corr.correlation > 0.96]
df_high_corr
# Out:
#                            variable1                  variable2  correlation
# 1672  back summer tires rim diameter  summer tires rim diameter     0.997407
# 2029  back winter tires rim diameter  winter tires rim diameter     0.993658
# 3095              description_length                 word_count     0.989647
# 1910   back winter tires apect ratio   winter tires apect ratio     0.979885
# 1553   back summer tires apect ratio   summer tires apect ratio     0.974668
# 1791          back winter tire width          winter tire width     0.962454

# %%
asd = pd.Series([1,2,3])
asd == asd.astype(float)
# Out:
# 0    True
# 1    True
# 2    True
# dtype: bool

# %%
'asd' in np.array(['as', 'a', 'asd'])
# Out:
# True

# %%
high_corr_values = df_high_corr['variable1'].values
high_corr_values
# Out:
# array(['back summer tires rim diameter', 'back winter tires rim diameter',
#        'description_length', 'back winter tires apect ratio',
#        'back summer tires apect ratio', 'back winter tire width'],
#       dtype=object)

# %%
df_melt_corr[df_melt_corr.variable1 == 'price (HUF)']
# Out:
#       variable1                  variable2  correlation
# 17  price (HUF)  winter tires rim diameter     0.624799
# 14  price (HUF)  summer tires rim diameter     0.612926
# 12  price (HUF)          summer tire width     0.551783
# 15  price (HUF)          winter tire width     0.544517
# 24  price (HUF)              speaker count     0.492361
# ..          ...                        ...          ...
# 88  price (HUF)                  tfidf_oil    -0.120344
# 36  price (HUF)             tfidf_exchange    -0.141112
# 85  price (HUF)            tfidf_technical    -0.141418
# 13  price (HUF)   summer tires apect ratio    -0.365782
# 16  price (HUF)   winter tires apect ratio    -0.379095
#
# [101 rows x 3 columns]

# %%
df_melt_corr[df_melt_corr.variable2 == 'price (HUF)']
# Out:
#                          variable1    variable2  correlation
# 11                    initial part  price (HUF)     0.932707
# 23  back winter tires rim diameter  price (HUF)     0.691729
# 9                 performance (kW)  price (HUF)     0.686560
# 20  back summer tires rim diameter  price (HUF)     0.683748
# 18          back summer tire width  price (HUF)     0.657869
# 21          back winter tire width  price (HUF)     0.654324
# 5                  own weight (kg)  price (HUF)     0.489578
# 8          cylinder capacity (cm3)  price (HUF)     0.433149
# 10             MOT is valid (days)  price (HUF)     0.226747
# 26              description_length  price (HUF)     0.193590
# 4                  number of doors  price (HUF)     0.000543
# 1                        financing  price (HUF)    -0.158683
# 2              clock position (km)  price (HUF)    -0.401970
# 19   back summer tires apect ratio  price (HUF)    -0.476919
# 22   back winter tires apect ratio  price (HUF)    -0.477292
# 25                        age_year  price (HUF)    -0.534770

# %%
# Drop 'inital part' since it almost identical to price
df2.drop(columns=['initial part'] +list(high_corr_values), inplace=True, errors='ignore')

# %%
# There are some extramely low prices where the price is written by mistace drop them
df2 = df2[df2['price (HUF)'] > 100000]

# %%
df2.to_parquet('../data/used_car_engineered_data.parquet')

# %%
df_hun_sattlements.to_csv('all_hun_sattlement.csv', index=False)

# %%
# Save descriptions to create a word cloud in EDA
text = '\n'.join(df['description'].dropna())

# %%
with open('descriptions.txt', 'w') as file:
    file.write(text)

# %%
df[tfidf_df['tfidf_sell']>0]['description'].values[:10]
# Out:
# array(['eladó egy új korában magyarországon, a renault miskolc-ban-ban vásárolt, és végig ott szervizelt, végig egy tulajdonos által használt, mindössze 110000 km-t futott, 90 lóerős, benzines, renault captur 0.9 tce energy alize euro 6. az autó kifogástalan műszaki állapotú, légkondicionálóval és rendeltetésszerűen működő egyéb extrafelszerelésekkel(tempomat\u200b, usb csatlakozós multimédia, elektromosan állítható-, fűthető visszapillantó tükrök, első-hátsó elektromos ablakemelők, tologatható hátsó üléssor, menetstabilizátor(esp), kipörgésgátló(asr), légzsákok(vezető, utas, oldal). a beltér tiszta, állapota tükrözi az alacsony futásteljesítményt. járműszolgáltatási platform-os lekérdezése, szervizszámlái megtekinthetőek a dokumentum fül alatt. mindkét gyári kulcskártyájával és az összes kezelési útmutatóval rendelkezik. a műszaki vizsga még több mint másfél évig érvényes. a gépkocsira egy év(igény szerint akár három) műszaki garanciát adunk. eladására új autó vásárlása miatt került sor. ______________________________\u200b__ 15 éves szakmai tapasztalattal alapított cégünk kizárólag magyarországon újonnan üzembe helyezett gépjárművek adás-vételével foglalkozik. a kilométeróra állás valódiságára, az autó és annak okmányainak jogi tisztaságára visszavásárlási garanciát adunk. a belügyminisztériumi (jszp-szüf) adatbázisból leellenőrzött, műszakilag átvizsgált, festékréteg mérővel leellenőrzött autókat értékesítünk. autóink leinformálhatóak, minden hirdetésünkben szerepel az autó alvázszáma és a rendszám sincs kitakarva! szolgáltatásaink továbbá: okmányirodai ügyintézés, kötelező-, casco-, műszaki biztosítás kötés, hitelügyintézés (mkb euroleasing), autóbeszámítás (olcsóbb-drágább). nyitva tartás: h-p 9-18-ig, szo 9-13-ig. a megtekintéshez időpont egyeztetés szükséges! konkrét vásárlási szándék esetén a nyitva tartási időn kívül is állunk rendelkezésükre!',
#        'volkswagen polo type 6c 1.2 tsi 90 allstar bmt eladó. kitűnő állapotú karosszéria, hibátlan kopás és szakadásmentes újszerű belső tér. számlákkal igazolt szerviztörténet. első-hátsó parkolóradar, tempomat, manuális klíma, fűthető első ülések, fűthető külső tükrök, esőszenzor, kartámasz, isofix, gyári szövet szőnyegek, méretpontos gumiszőnyegek, pótkerék, emelő. jó állapotú bridgestone nyári gumik gyári volkswagen alufelnin, újszerű állapotú hankook téligumik lemezfelnin, gyári volkswagen dísztárcsákkal. 2db gyári kulcs. 3 év műszaki garancia, akár korlátlan km futással. alvázszám szerint leinformálható előélet: wvwzzz6rzhy088684. készleten lévő autó. budapesten a telephelyünkön rugalmasan megtekinthető és hitelre 20%-tól elvihető. teljeskörű hitel-, lízing- és biztosítás ügyintézés. a hirdetésben szereplő finanszírozási kalkuláció tájékoztató jellegű, nem jelent a finanszírozó részéről kötelezettségvállalást és annak módosítására is kizárólag a finanszírozó jogosult. a legnagyobb igyekezetünk és odafigyelésünk ellenére is szerepelhetnek a hirdetésben hibák, ezért a fenti tájékoztatás nem minősül a polgári törvénykönyvről szóló 2013. évi v. törvény szerinti ajánlatnak, így nem fűződik hozzá ajánlati kötöttség sem. autóinkat előre egyeztetett időpontban lehet megtekinteni. az m0-m3 találkozásától 1 percre - auto26. gps: auto26, a sorompót érkezésekor kérésre nyitjuk.',
#        'volkswagen passat variant 1.4 tsi eladó. szép állapotú, korróziómentes karosszéria, kopás és szakadásmentes, újszerű belső tér. comfortline felszereltség. dsg váltó, navigáció, multifunkcionális kormány, kétzónás digitális klíma, fűthető első ülések, hűthető kesztyűtartó, első-hátsó kartámasz, parkolóradar elöl-hátul, isofix, ködlámpa, pótkerék, emelő. végig vezetett szervizkönyv. frissen elvégzett nagyszerviz, váltóolaj, motorolaj, szűrők, gyertyák. újszerű állapotú, michelin négyévszakos gumik, gyári volkswagen alufelnin. 3 év műszaki garancia, akár korlátlan km futással. alvázszám szerint leinformálható előélet: wvwzzz3czfe045549. készleten lévő autó. budapesten a telephelyünkön rugalmasan megtekinthető és hitelre 20%-tól elvihető. teljeskörű hitel-, lízing- és biztosítás ügyintézés. a hirdetésben szereplő finanszírozási kalkuláció tájékoztató jellegű, nem jelent a finanszírozó részéről kötelezettségvállalást és annak módosítására is kizárólag a finanszírozó jogosult. a legnagyobb igyekezetünk és odafigyelésünk ellenére is szerepelhetnek a hirdetésben hibák, ezért a fenti tájékoztatás nem minősül a polgári törvénykönyvről szóló 2013. évi v. törvény szerinti ajánlatnak, így nem fűződik hozzá ajánlati kötöttség sem. autóinkat előre egyeztetett időpontban lehet megtekinteni. az m0-m3 találkozásától 1 percre - auto26. gps: auto26, a sorompót érkezésekor kérésre nyitjuk.',
#        'toyota auris touring sports 1.8 hsd eladó. kitűnő állapotú karosszéria, kopás és szakadás mentes belső tér. magyarországi, végig toyota márkaszervizben karbantartott autó. magasan felszerelt. bőrkormány, ülésfűtés, első-hátsó parkolóradar, tolatókamera, parkoló asszisztens, sávelhagyásra figyelmeztető rendszer, ütközés veszélyre felkészítő rendszer, esőérzékelő, navigáció, isofix. jó állapotú goodyear négyévszakos gumik, gyári toyota alufelnin. elektronikus szervizkönyv. alvázszám szerint leinformálható előélet: sb1zs3je40e379590. 3 év kiterjesztett garancia. készleten lévő autó. budapesten a telephelyünkön rugalmasan megtekinthető és hitelre 20%-tól elvihető. teljeskörű hitel-, lízing- és biztosítás ügyintézés. a legnagyobb igyekezetünk és odafigyelésünk ellenére is szerepelhetnek a hirdetésben hibák, ezért a fenti tájékoztatás nem minősül a polgári törvénykönyvről szóló 2013. évi v. törvény szerinti ajánlatnak, így nem fűződik hozzá ajánlati kötöttség sem. autóinkat előre egyeztetett időpontban lehet megtekinteni. az m0-m3 találkozásától 1 percre - auto26. gps: auto26, a sorompót érkezésekor kérésre nyitjuk.',
#        'volvo v60 plug-in hybrid eladó! korát meghazudtoló állapot. 200 000 km alatti futásteljesítmény. fényezésmentes, gyári karosszéria, kopás és szakadásmentes belső tér. legmagasabb summum felszereltség. memóriás vezetőülés, fűthető első-hátsó ülések, kormányfűtés, navigáció, volvo city safety, bőrbelső, első-hátsó parkolóradar, kétzónás digitális klíma. újszerű állapotú laufenn nyári gumik, gyári volvo alufelnin. type 2 töltőkábel. 3 év kiterjesztett garancia! a dokumentumok fül alatt található az autó reportja. készleten lévő autó. budapesten a telephelyünkön rugalmasan megtekinthető és hitelre 20%-tól elvihető. teljeskörű hitel-, lízing- és biztosítás ügyintézés. a legnagyobb igyekezetünk és odafigyelésünk ellenére is szerepelhetnek a hirdetésben hibák, ezért a fenti tájékoztatás nem minősül a polgári törvénykönyvről szóló 2013. évi v. törvény szerinti ajánlatnak, így nem fűződik hozzá ajánlati kötöttség sem. autóinkat előre egyeztetett időpontban lehet megtekinteni. az m0-m3 találkozásától 1 percre - auto26. gps: auto26, a sorompót érkezésekor kérésre nyitjuk.',
#        "bmw 330d xdrive eladó! gyönyörű állapotú külső-belső, hibátlan műszaki állapot. magasan felszerelt. panoráma üvegtető, elektromosan behajtható vonóhorog, csomagrögzítő, touchpad, hátsó napfényvédő rolók, tempomat, comb és deréktámaszos első ülések, kartámasz, automata fényszóró. 2db gyári kulcs. jelenleg az autón újszerű bridgestone nyári gumik vannak, gyári '18 bmw alufelnin. 3 év kiterjesztett garancia. budapesten a telephelyünkön rugalmasan megtekinthető és hitelre 20%-tól elvihető. teljeskörű hitel-, lízing- és biztosítás ügyintézés. a legnagyobb igyekezetünk és odafigyelésünk ellenére is szerepelhetnek a hirdetésben hibák, ezért a fenti tájékoztatás nem minősül a polgári törvénykönyvről szóló 2013. évi v. törvény szerinti ajánlatnak, így nem fűződik hozzá ajánlati kötöttség sem. autóinkat előre egyeztetett időpontban lehet megtekinteni. az m0-m3 találkozásától 1 percre - auto26. gps: auto26, a sorompót érkezésekor kérésre nyitjuk.",
#        'mercedes-benz gle 350 d 4matic eladó! nagyon szép karosszéria, csupán néhány használatból eredő nyom, kopás és szakadásmentes belső tér. magasan felszerelt. memóriás vezetőülés, bőrbelső, automata klíma, távolságtartó tempomat, holttér figyelő rendszer, sávtartó asszisztens, fáradtság-érzékelő, ráfutás-érzékelő, esőérzékelő. újszerű hankook nyári gumik, gyári mercedes-benz alufelnin. alvázszám szerint leinformálható előélet: wdc1660241a621405. 3 év kiterjesztett garancia. készleten lévő autó. budapesten a telephelyünkön rugalmasan megtekinthető és hitelre 20%-tól elvihető. teljeskörű hitel-, lízing- és biztosítás ügyintézés. a legnagyobb igyekezetünk és odafigyelésünk ellenére is szerepelhetnek a hirdetésben hibák, ezért a fenti tájékoztatás nem minősül a polgári törvénykönyvről szóló 2013. évi v. törvény szerinti ajánlatnak, így nem fűződik hozzá ajánlati kötöttség sem. autóinkat előre egyeztetett időpontban lehet megtekinteni. az m0-m3 találkozásától 1 percre - auto26. gps: auto26, a sorompót érkezésekor kérésre nyitjuk.',
#        'fiat 500e icon 42kwh eladó! új autó. gyönyörű karcmentes karosszéria, különleges külső szín. használatmentes belső tér, mindössze 1100 futott kilométer. nagyon magas icon felszereltség. gyári garanciás autó, kiterjeszthető akár 8 év teljeskörű garancia. magyar rendszámmal rendelkezik, azonnal elvihető. a vételár 27% áfá-t tartalmaz. alvázszám szerint leinformálható előélet: zfaefac40nx051416. készleten lévő új autó. budapesten a telephelyünkön rugalmasan megtekinthető és hitelre 20%-tól elvihető. teljeskörű hitel-, lízing- és biztosítás ügyintézés. a legnagyobb igyekezetünk és odafigyelésünk ellenére is szerepelhetnek a hirdetésben hibák, ezért a fenti tájékoztatás nem minősül a polgári törvénykönyvről szóló 2013. évi v. törvény szerinti ajánlatnak, így nem fűződik hozzá ajánlati kötöttség sem. autóinkat előre egyeztetett időpontban lehet megtekinteni. az m0-m3 találkozásától 1 percre - auto26. gps: auto26, a sorompót érkezésekor kérésre nyitjuk.',
#        "volvo s90 inscription eladó! gyönyörű állapotú külső-belső, hibátlan műszaki állapot. legmagasabb felszereltség. sávtartó automatika, távolságtartó tempomat, comb és deréktámaszos fűthető első ülések, memóriás vezetőülés, deréktámasz, kartámasz, automata fényszóró, esőszenzor, apple carplay, android auto, faberakás. végig vezetett szervizkönyv. 2db gyári kulcs. jelenleg az autón újszerű michelin nyári gumik vannak, gyári '19 volvo alufelnin. 3 év kiterjesztett garancia. budapesten a telephelyünkön rugalmasan megtekinthető és hitelre 20%-tól elvihető. teljeskörű hitel-, lízing- és biztosítás ügyintézés. a legnagyobb igyekezetünk és odafigyelésünk ellenére is szerepelhetnek a hirdetésben hibák, ezért a fenti tájékoztatás nem minősül a polgári törvénykönyvről szóló 2013. évi v. törvény szerinti ajánlatnak, így nem fűződik hozzá ajánlati kötöttség sem. autóinkat előre egyeztetett időpontban lehet megtekinteni. az m0-m3 találkozásától 1 percre - auto26. gps: auto26, a sorompót érkezésekor kérésre nyitjuk.",
#        'eladó a képeken látható mini countryman cooper d automata! sérülésmentes, jól felszerelt, 35 e km-el, 2 év garanciával! kérem pontos felszereltségért és részletekért keresse kollégáinkat az elérhetőségek valamelyikén, vagy személyesen márkakereskedésünkben! linartech autóház kft, bmw márkakereskedés és szervíz kecskemét.'],
#       dtype=object)
